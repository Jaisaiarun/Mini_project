# %%
import pandas as pd

# %%
data = pd.read_csv("dataset.csv")#dataset before preprocessing
display(data.head())
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal  num
# 0  0.0   6.0    0
# 1  3.0   3.0    2
# 2  2.0   7.0    1
# 3  0.0   3.0    0
# 4  0.0   3.0    0

# %%
data.isnull().sum()#Null values identification
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# num         0
# dtype: int64

# %%
#Dropping rows with Null value
print("Shape before droping: ")
print(data.shape)
data=data.dropna()
print("Shape after droping: ")
print(data.shape)
print(data.isnull().sum())
# Out:
# Shape before droping:
# (303, 14)
# Shape after droping:
# (297, 14)
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
#Changing the multiclass label to binary
data['num'] = data.num.map({0: 0, 1: 1, 2: 1, 3: 1, 4: 1})
display(data)
#df['thal'] = df.thal.fillna(df.thal.mean())
#df['ca'] = df.ca.fillna(df.ca.mean())
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   57    0   4       140   241    0        0      123      1      0.2
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
#
#      slope   ca  thal  num
# 0        3  0.0   6.0    0
# 1        2  3.0   3.0    1
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
num_count  = data['num'].value_counts()
plt.figure(figsize=(10,5))
sns.barplot(num_count.index, num_count.values, alpha=0.8)
plt.title('Heart Disease Count')
plt.ylabel('Count', fontsize=12)
plt.xlabel('Heart Disease ', fontsize=12)
plt.show()
# Out:
# C:\Users\anura\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.num.value_counts()
# Out:
# 0    160
# 1    137
# Name: num, dtype: int64

# %%
#Dataset after preprocessing
data.to_csv(r'D:\sem7mat\miniPro\dataset\cleveland\processedDataset.csv', index=False)
